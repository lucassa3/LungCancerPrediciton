# %% [markdown]
# # ImagePreprocessing
#
# Getting patient ct lung scans. Each patient has hundreds of slices, each one of them being 2d scans of their lungs. In this notebook we get the top three slices of each patient that has been marked with having the biggest detected nodules inside their lungs. We then treat that data to segment only the lungs on each scan, and make an image mask that contains the location of the biggest node detected in their respective scan. After all of that, we build a set of lung images and label images.
#
# This code was extracted and slightly modified from the [Data Science Bowl 2017 contest](https://www.kaggle.com/c/data-science-bowl-2017#description) getting started tutorial. The source code can be found [here](https://github.com/booz-allen-hamilton/DSB3Tutorial).

# %%
import SimpleITK as sitk
import numpy as np
import csv
from glob import glob
import pandas as pd

# %%
input_path = "../sets/"
output_path = "../outs/"

file_list=glob(input_path+"*.mhd")

# %%
# Helper function to get rows in data frame associated with each file
def get_filename(case):
    global file_list
    for f in file_list:
        if case in f:
            return(f)

# %%
def make_mask(center,diam,z,width,height,spacing,origin):
    
    '''
    Center : centers of circles px -- list of coordinates x,y,z
    diam : diameters of circles px -- diameter
    widthXheight : pixel dim of image
    spacing = mm/px conversion rate np array x,y,z
    origin = x,y,z mm np.array
    z = z position of slice in world coordinates mm
    '''
    
    mask = np.zeros([height,width]) # 0's everywhere except nodule swapping x,y to match img
    #convert to nodule space from world coordinates

    # Defining the voxel range in which the nodule falls
    v_center = (center-origin)/spacing
    v_diam = int(diam/spacing[0]+5)
    v_xmin = np.max([0,int(v_center[0]-v_diam)-5])
    v_xmax = np.min([width-1,int(v_center[0]+v_diam)+5])
    v_ymin = np.max([0,int(v_center[1]-v_diam)-5]) 
    v_ymax = np.min([height-1,int(v_center[1]+v_diam)+5])

    v_xrange = range(v_xmin,v_xmax+1)
    v_yrange = range(v_ymin,v_ymax+1)

    # Convert back to world coordinates for distance calculation
    x_data = [x*spacing[0]+origin[0] for x in range(width)]
    y_data = [x*spacing[1]+origin[1] for x in range(height)]

    # Fill in 1 within sphere around nodule
    for v_x in v_xrange:
        for v_y in v_yrange:
            p_x = spacing[0]*v_x + origin[0]
            p_y = spacing[1]*v_y + origin[1]
            if np.linalg.norm(center-np.array([p_x,p_y,z]))<=diam:
                mask[int((p_y-origin[1])/spacing[1]),int((p_x-origin[0])/spacing[0])] = 1.0
    return(mask)

# %%
def matrix2int16(matrix):
    ''' 
matrix must be a numpy array NXN
Returns uint16 version
    '''
    m_min= np.min(matrix)
    m_max= np.max(matrix)
    #matrix = matrix-m_min  # Isto e um bug no codigo original.
    return(np.array(np.rint( (matrix-m_min)/float(m_max-m_min) * 65535.0),dtype=np.uint16))

# %% [markdown]
# ## 1. Retrieving the images and saving top 3 slices and masks

# %%
# The locations of the nodes
df_node = pd.read_csv("../annotations.csv")
df_node["file"] = df_node["seriesuid"].apply(get_filename)

df_node = df_node.dropna()

# Looping over the image files
fcount = 0

fcount = 0
for img_file in file_list:
    print ("Getting mask for image file %s" % img_file.replace(input_path,""))
    mini_df = df_node[df_node["file"]==img_file] #constroi um mini-df com infos de nodulos pra cada file
    if len(mini_df)>0:    # pulas as slices sem nodulos 
        biggest_node = np.argsort(mini_df["diameter_mm"].values)[-1]   # pega dados do maior nodulo
        node_x = mini_df["coordX"].values[biggest_node]
        node_y = mini_df["coordY"].values[biggest_node]
        node_z = mini_df["coordZ"].values[biggest_node]
        diam = mini_df["diameter_mm"].values[biggest_node]
        #
        # extracting image
        #
        itk_img = sitk.ReadImage(img_file) #pega imagem
        img_array = sitk.GetArrayFromImage(itk_img) #indexes are z,y,x --pega dados da imagem
        num_z,height,width = img_array.shape        #heightXwidth constitute the transverse plane
        imgs = np.ndarray([3,height,width],dtype=np.uint16)
        masks = np.ndarray([3,height,width],dtype=np.uint8)
        center = np.array([node_x,node_y,node_z])  #centro do nodulo
        origin = np.array(itk_img.GetOrigin()) #x,y,z  Origin in world coordinates (mm)
        spacing = np.array(itk_img.GetSpacing())# spacing of voxels in world coor. (mm) --transforma dimensao da img em mm
        v_center =np.rint((center-origin)/spacing)  # nodule center in voxel space --encaixa local do nodulo na img
        #
        # for each slice in the image, convert the image data to the uint16 range
        # and generate a binary mask for the nodule location
        #
        i = 0
        for i_z in range(int(v_center[2])-1,int(v_center[2])+2):
            mask = make_mask(center,diam,i_z*spacing[2]+origin[2],width,height,spacing,origin)
            masks[i] = mask
            imgs[i] = matrix2int16(img_array[i_z])
            i+=1


        np.save(output_path+"images_%d.npy" % (fcount) ,imgs)
        np.save(output_path+"masks_%d.npy" % (fcount) ,masks)
        fcount+=1
# Out:
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926682752765845212286.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482151095585000946543.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163890911914061745866.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028192176989979435275.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.102133688497886810253331438797.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.103115201714075993579787468219.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760173137525888934217.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.104780906131535625872840889059.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370116976238911317774.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.106719103982792863757268101375.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.108231420525711026834210228428.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.111017101339429664883879536171.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.113586291551175790743673929831.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.113697708991260454310623082679.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.114195693932194925962391697338.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.114218724025049818743426522343.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.115386642382564804180764325545.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.116492508532884962903000261147.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.117383608379722740629083782428.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.119806527488108718706404165837.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.121824995088859376862458155637.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.121993590721161347818774929286.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.123697637451437522065941162930.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.124663713663969377020085460568.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.125067060506283419853742462394.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.125356649712550043958727288500.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.126121460017257137098781143514.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596873065041988320084.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.126704785377921920210612476953.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.127965161564033605177803085629.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.128059192202504367870633619224.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.128881800399702510818644205032.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.133378195429627807109985347209.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.134370886216012873213579659366.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.135657246677982059395844827629.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.137375498893536422914241295628.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.138080888843357047811238713686.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.139444426690868429919252698606.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.139595277234735528205899724196.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.139713436241461669335487719526.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.140527383975300992150799777603.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.141430002307216644912805017227.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.141511313712034597336182402384.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.142154819868944114554521645782.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.142485715518010940961688015191.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.143412474064515942785157561636.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.144438612068946916340281098509.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.144883090372691745980459537053.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.144943344795414353192059796098.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.145283812746259413053188838096.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.145474881373882284343459153872.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.145759169833745025756371695397.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.146429221666426688999739595820.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.146603910507557786636779705509.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.147250707071097813243473865421.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.148229375703208214308676934766.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.149463915556499304732434215056.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.152684536713461901635595118048.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.154703816225841204080664115280.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.156322145453198768801776721493.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.156579001330474859527530187095.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.156821379677057223126714881626.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.159521777966998275980367008904.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.159996104466052855396410079250.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.160216916075817913953530562493.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.161002239822118346732951898613.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.161073793312426102774780216551.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.162207236104936931957809623059.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.162718361851587451505896742103.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.162845309248822193437735868939.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.162901839201654862079549658100.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.163901773171373940247829492387.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.163931625580639955914619627409.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.163994693532965040247348251579.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.164988920331211858091402361989.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.167919147233131417984739058859.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.168037818448885856452592057286.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.168605638657404145360275453085.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.169128136262002764211589185953.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.171667800241622018839592854574.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.171919524048654494439256263785.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.172573195301625265149778785969.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.172845185165807139298420209778.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.173101104804533997398137418032.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.173106154739244262091404659845.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.176362912420491262783064585333.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.177252583002664900748714851615.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.177685820605315926524514718990.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.177785764461425908755977367558.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.177985905159808659201278495182.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.178680586845223339579041794709.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636438705059720603192.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.179162671133894061547290922949.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.179730018513720561213088132029.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.183184435049555024219115904825.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.183843376225716802567192412456.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.183924380327950237519832859527.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.184019785706727365023450012318.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.184412674007117333405073397832.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.185226274332527104841463955058.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.186021279664749879526003668137.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.189483585244687808087477024767.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.190298296009658115773239776160.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.191266041369462391833537519639.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.191301539558980174217770205256.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.191617711875409989053242965150.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.192419869605596446455526220766.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.193408384740507320589857096592.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.193808128386712859512130599234.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.194465340552956447447896167830.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.194488534645348916700259325236.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.197987940182806628828566429132.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.199069398344356765037879821616.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.199171741859530285887752432478.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.199220738144407033276946096708.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.199670099218798685977406484591.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.199975006921901879512837687266.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.200558451375970945040979397866.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.200837896655745926888305239398.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.202464973819273687476049035824.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.202476538079060560282495099956.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.202643836890896697853521610450.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.203179378754043776171267611064.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.203741923654363010377298352671.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.204802250386343794613980417281.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.205852555362702089950453265567.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.205993750485568250373835565680.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.206539885154775002929031534291.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.208511362832825683639135205368.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.208737629504245244513001631764.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.209269973797560820442292189762.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.210426531621179400035178209430.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.210837812047373739447725050963.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.211051626197585058967163339846.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.211071908915618528829547301883.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.211956804948320236390242845468.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.212346425055214308006918165305.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.213022585153512920098588556742.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.215086589927307766627151367533.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.216252660192313507027754194207.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.216526102138308489357443843021.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.216652640878960522552873394709.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421986638139451480826.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.217697417596902141600884006982.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.217955041973656886482758642958.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.218476624578721885561483687176.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.219349715895470349269596532320.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.220205300714852483483213840572.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.221945191226273284587353530424.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.222087811960706096424718056430.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.223098610241551815995595311693.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.225154811831720426832024114593.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.226383054119800793308721198594.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.226456162308124493341905600418.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.227885601428639043345478571594.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.229664630348267553620068691756.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.230078008964732806419498631442.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.230416590143922549745658357505.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.231002159523969307155990628066.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.231645134739451754302647733304.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.231834776365874788440767645596.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.232011770495640253949434620907.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.232058316950007760548968840196.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.232071262560365924176679652948.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.235364978775280910367690540811.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.237428977311365557972720635401.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.238522526736091851696274044574.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.240969450540588211676803094518.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.241570579760883349458693655367.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.242761658169703141430370511586.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.243094273518213382155770295147.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.244204120220889433826451158706.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.244447966386688625240438849169.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.244590453955380448651329424024.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.244681063194071446501270815660.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.247769845138587733933485039556.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.248357157975955379661896491341.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.249530219848512542668813996730.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.250397690690072950000431855143.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.250438451287314206124484591986.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.250863365157630276148828903732.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.252358625003143649770119512644.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.252634638822000832774167856951.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.252697338970999211181671881792.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.253283426904813468115158375647.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.253322967203074795232627653819.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.254254303842550572473665729969.mhd
# C:\Users\lucas\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in short_scalars
#   if __name__ == '__main__':
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.259018373683540453277752706262.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.259227883564429312164962953756.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.259543921154154401875872845498.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.261678072503577216586082745513.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.264090899378396711987322794314.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.265133389948279331857097127422.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.265775376735520890308424143898.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.265960756233787099041040311282.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.267519732763035023633235877753.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.268589491017129166376960414534.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.268838889380981659524993261082.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.268992195564407418480563388746.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.269075535958871753309238331179.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.269689294231892620436462818860.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.270152671889301412052226973069.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.270215889102603268207599305185.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.270390050141765094612147226290.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.272042302501586336192628818865.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.272190966764020277652079081128.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.272259794130271010519952623746.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.272961322147784625028175033640.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.274052674198758621258447180130.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.275007193025729362844652516689.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.275766318636944297772360944907.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.276556509002726404418399209377.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.276710697414087561012670296643.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.277445975068759205899107114231.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.277662902666135640561346462196.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.278010349511857248000260557753.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.278660284797073139172446973682.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.280972147860943609388015648430.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.281489753704424911132261151767.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.281967919138248195763602360723.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.282512043257574309474415322775.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.283569726884265181140892667131.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.283733738239331719775105586296.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.286647622786041008124419915089.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.287560874054243719452635194040.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.293593766328917170359373773080.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.293757615532132808762625441831.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.294188507421106424248264912111.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.295298571102631191572192562523.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.295420274214095686326263147663.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.296863826932699509516219450076.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.300146276266881736689307479986.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.300246184547502297539521283806.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.300271604576987336866436407488.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.302134342469412607966016057827.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.302557165094691896097534021075.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.303421828981831854739626597495.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.303865116731361029078599241306.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.304676828064484590312919543151.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.304700823314998198591652152637.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.305858704835252413616501469037.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.306788423710427765311352901943.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.307835307280028057486413359377.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.308183340111270052562662456038.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.309672797925724868457151381131.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.310395752124284049604069960014.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.310548927038333190233889983845.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.310626494937915759224334597176.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.311236942972970815890902714604.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.311981398931043315779172047718.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.313283554967554803238484128406.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.313334055029671473836954456733.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.313605260055394498989743099991.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.313835996725364342034830119490.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.314519596680450457855054746285.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.314789075871001236641548593165.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.315214756157389122376518747372.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.316393351033132458296975008261.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.317087518531899043292346860596.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.319009811633846643966578282371.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.319066480138812986026181758474.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.320111824803959660037459294083.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.320967206808467952819309001585.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.321465552859463184018938648244.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.323302986710576400812869264321.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.323541312620128092852212458228.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.323753921818102744511069914832.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.323859712968543712594665815359.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.324567010179873305471925391582.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.325164338773720548739146851679.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.325580698241281352835338693869.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.326057189095429101398977448288.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.329326052298830421573852261436.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.330425234131526435132846006585.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.331211682377519763144559212009.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.332453873575389860371315979768.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.333145094436144085379032922488.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.333319057944372470283038483725.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.334022941831199910030220864961.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.334105754605642100456249422350.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.334517907433161353885866806005.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.335866409407244673864352309754.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.336225579776978874775723463327.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.336894364358709782463716339027.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.337845202462615014431060697507.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.339142594937666268384335506819.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.339546614783708685476232944897.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.367204840301639918160517361062.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.385151742584074711135621089321.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.390009458146468860187238398197.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.390513733720659266816639651938.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.395623571499047043765181005112.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.397062004302272014259317520874.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.398955972049286139436103068984.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.401389720232123950202941034290.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.404364125369979066736354549484.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.404768898286087278137462774930.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.417815314896088956784723476543.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.419601611032172899567156073142.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.428038562098395445838061018440.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.430109407146633213496148200410.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.438308540025607517017949816111.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.443400977949406454649939526179.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.449254134266555649028108149727.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.450501966058662668272378865145.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.458525794434429386945463560826.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.461155505515403114280165935891.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.463214953282361219537913355115.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.466284753932369813717081722101.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.470912100568074901744259213968.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.479402560265137632920333093071.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.487745546557477250336016826588.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.503980049263254396021509831276.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.504324996863016748259361352296.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.525937963993475482158828421281.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.534083630500464995109143618896.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.557875302364105947813979213632.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.561458563853929400124470098603.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.564534197011295112247542153557.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.566816709786169715745131047975.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.584871944187559733312703328980.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.603166427542096384265514998412.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.614147706162329660656328811671.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.616033753016904899083676284739.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.619372068417051974713149104919.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.621916089407825046337959219998.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.624425075947752229712087113746.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.625270601160880745954773142570.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.631047517458234322522264161877.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.640729228179368154416184318668.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.655242448149322898770987310561.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.657775098760536289051744981056.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.663019255629770796363333877035.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.669518152156802508672627785405.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.670107649586205629860363487713.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.674809958213117379592437424616.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.690929968028676628605553365896.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.692598144815688523679745963696.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.707218743153927597786179232739.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.710845873679853791427022019413.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.716498695101447665580610403574.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.724251104254976962355686318345.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.741709061958490690246385302477.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.743969234977916254223533321294.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.752756872840730509471096155114.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.756684168227383088294595834066.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.768276876111112560631432843476.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.776429308535398795601496131524.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.779493719385047675154892222907.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.780558315515979171413904604168.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.797637294244261543517154417124.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.799582546798528864710752164515.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.801945620899034889998809817499.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.802595762867498341201607992711.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.803808126682275425758092691689.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.805925269324902055566754756843.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.811825890493256320617655474043.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.822128649427327893802314908658.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.826812708000318290301835871780.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.832260670372728970918746541371.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.842317928015463083368074520378.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.850739282072340578344345230132.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.861997885565255340442123234170.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.885168397833922082085837240429.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.885292267869246639232975687131.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.888291896309937415860209787179.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.892375496445736188832556446335.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.898642529028521482602829374444.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.910607280658963002048724648683.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.922852847124879997825997808179.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.935683764293840351008008793409.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.939152384493874708850321969356.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.952265563663939823135367733681.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.961063442349005937536597225349.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.965620538050807352935663552285.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.969607480572818589276327766720.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.970264865033574190975654369557.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.970428941353693253759289796610.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.975254950136384517744116790879.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.975426625618184773401026809852.mhd
# Getting mask for image file ../sets\1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707182900091062408058.mhd

# %%
import matplotlib.pyplot as plt


# %matplotlib notebook

mask_filename = '../outs/masks_0.npy'
masks = np.load(mask_filename)

for i in range(3):
    print ("image %d" % i)
    
    fig,ax = plt.subplots(2,2,figsize=[8,8])

    ax[0,1].imshow(masks[i],cmap='gray') #mascara nodulo annotations.csv correspondente
    
    plt.show()
# Out:
# image 0
# <img src="data:image/png;base64,..." width="800">
# image 1
# <img src="data:image/png;base64,..." width="800">
# image 2
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 2. Creating the lung masks

# %%
from skimage import morphology
from skimage import measure
from sklearn.cluster import KMeans
from skimage.transform import resize

# %%
file_list=glob(output_path+ "images_*.npy")

for img_file in file_list:
    # I ran into an error when using Kmean on np.float16, so I'm using np.float64 here
    imgs_to_process = np.load(img_file).astype(np.float64) 
    print ("on image", img_file)
    for i in range(len(imgs_to_process)):
        img = imgs_to_process[i]
        #Standardize the pixel values
        mean = np.mean(img)
        std = np.std(img)
        img = img-mean
        img = img/std

        # Find the average pixel value near the lungs
        # to renormalize washed out images
        middle = img[100:400,100:400] 
        mean = np.mean(middle)  
        max = np.max(img)
        min = np.min(img)
        # To improve threshold finding, I'm moving the 
        # underflow and overflow on the pixel spectrum
        img[img==max]=mean
        img[img==min]=mean

        #plt.hist(img.flatten(),bins=200)
        

        # Using Kmeans to separate foreground (radio-opaque tissue)
        # and background (radio transparent tissue ie lungs)
        # Doing this only on the center of the image to avoid 
        # the non-tissue parts of the image as much as possible
        #
        valid_values = np.reshape(middle,[np.prod(middle.shape),1])
        kmeans = KMeans(n_clusters=2).fit(valid_values)
        centers = sorted(kmeans.cluster_centers_.flatten())
        threshold = np.mean(centers)
        thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image
        
        eroded = morphology.erosion(thresh_img,np.ones([4,4]))
        dilation = morphology.dilation(eroded,np.ones([10,10]))
        labels = measure.label(dilation)

        regions = measure.regionprops(labels)
        good_labels = []
        for prop in regions:
            B = prop.bbox
            if B[2]-B[0]<475 and B[3]-B[1]<475 and B[0]>40 and B[2]<472:
                good_labels.append(prop.label)

        mask = np.ndarray([512,512],dtype=np.int8)
        mask[:] = 0
        #
        #  The mask here is the mask for the lungs--not the nodes
        #  After just the lungs are left, we do another large dilation
        #  in order to fill in and out the lung mask 
        #
        for N in good_labels:
            mask = mask + np.where(labels==N,1,0)
        
        mask = morphology.dilation(mask,np.ones([10,10])) # one last dilation
        
        imgs_to_process[i] = mask

    np.save(img_file.replace("images","lungmask"),imgs_to_process)
# Out:
# on image ../outs\images_0.npy
# on image ../outs\images_1.npy
# on image ../outs\images_10.npy
# on image ../outs\images_100.npy
# on image ../outs\images_101.npy
# on image ../outs\images_102.npy
# on image ../outs\images_103.npy
# on image ../outs\images_104.npy
# on image ../outs\images_105.npy
# on image ../outs\images_106.npy
# on image ../outs\images_107.npy
# on image ../outs\images_108.npy
# on image ../outs\images_109.npy
# on image ../outs\images_11.npy
# on image ../outs\images_110.npy
# on image ../outs\images_111.npy
# on image ../outs\images_112.npy
# on image ../outs\images_113.npy
# on image ../outs\images_114.npy
# on image ../outs\images_115.npy
# on image ../outs\images_116.npy
# on image ../outs\images_117.npy
# on image ../outs\images_118.npy
# on image ../outs\images_119.npy
# on image ../outs\images_12.npy
# on image ../outs\images_120.npy
# on image ../outs\images_121.npy
# on image ../outs\images_122.npy
# on image ../outs\images_123.npy
# on image ../outs\images_124.npy
# on image ../outs\images_125.npy
# on image ../outs\images_126.npy
# on image ../outs\images_127.npy
# on image ../outs\images_128.npy
# on image ../outs\images_129.npy
# on image ../outs\images_13.npy
# on image ../outs\images_130.npy
# on image ../outs\images_131.npy
# on image ../outs\images_132.npy
# on image ../outs\images_133.npy
# on image ../outs\images_134.npy
# on image ../outs\images_135.npy
# on image ../outs\images_136.npy
# on image ../outs\images_137.npy
# on image ../outs\images_138.npy
# on image ../outs\images_139.npy
# on image ../outs\images_14.npy
# on image ../outs\images_140.npy
# on image ../outs\images_141.npy
# on image ../outs\images_142.npy
# on image ../outs\images_143.npy
# on image ../outs\images_144.npy
# on image ../outs\images_145.npy
# on image ../outs\images_146.npy
# on image ../outs\images_147.npy
# on image ../outs\images_148.npy
# on image ../outs\images_149.npy
# on image ../outs\images_15.npy
# on image ../outs\images_150.npy
# on image ../outs\images_151.npy
# on image ../outs\images_152.npy
# on image ../outs\images_153.npy
# on image ../outs\images_154.npy
# on image ../outs\images_155.npy
# on image ../outs\images_156.npy
# on image ../outs\images_157.npy
# on image ../outs\images_158.npy
# on image ../outs\images_159.npy
# on image ../outs\images_16.npy
# on image ../outs\images_160.npy
# on image ../outs\images_161.npy
# on image ../outs\images_162.npy
# on image ../outs\images_163.npy
# on image ../outs\images_164.npy
# on image ../outs\images_165.npy
# on image ../outs\images_166.npy
# on image ../outs\images_167.npy
# on image ../outs\images_168.npy
# on image ../outs\images_169.npy
# on image ../outs\images_17.npy
# on image ../outs\images_170.npy
# on image ../outs\images_171.npy
# on image ../outs\images_172.npy
# on image ../outs\images_173.npy
# on image ../outs\images_174.npy
# on image ../outs\images_175.npy
# on image ../outs\images_176.npy
# on image ../outs\images_177.npy
# on image ../outs\images_178.npy
# on image ../outs\images_179.npy
# on image ../outs\images_18.npy
# on image ../outs\images_180.npy
# on image ../outs\images_181.npy
# on image ../outs\images_182.npy
# on image ../outs\images_183.npy
# on image ../outs\images_184.npy
# on image ../outs\images_185.npy
# on image ../outs\images_186.npy
# on image ../outs\images_187.npy
# on image ../outs\images_188.npy
# on image ../outs\images_189.npy
# on image ../outs\images_19.npy
# on image ../outs\images_190.npy
# on image ../outs\images_191.npy
# on image ../outs\images_192.npy
# on image ../outs\images_193.npy
# on image ../outs\images_194.npy
# on image ../outs\images_195.npy
# on image ../outs\images_196.npy
# on image ../outs\images_197.npy
# on image ../outs\images_198.npy
# on image ../outs\images_199.npy
# on image ../outs\images_2.npy
# on image ../outs\images_20.npy
# on image ../outs\images_200.npy
# on image ../outs\images_201.npy
# on image ../outs\images_202.npy
# on image ../outs\images_203.npy
# on image ../outs\images_204.npy
# on image ../outs\images_205.npy
# on image ../outs\images_206.npy
# on image ../outs\images_207.npy
# on image ../outs\images_208.npy
# on image ../outs\images_209.npy
# on image ../outs\images_21.npy
# on image ../outs\images_210.npy
# on image ../outs\images_211.npy
# on image ../outs\images_212.npy
# on image ../outs\images_213.npy
# on image ../outs\images_214.npy
# on image ../outs\images_215.npy
# on image ../outs\images_216.npy
# on image ../outs\images_217.npy
# on image ../outs\images_218.npy
# on image ../outs\images_219.npy
# on image ../outs\images_22.npy
# on image ../outs\images_220.npy
# on image ../outs\images_221.npy
# on image ../outs\images_222.npy
# on image ../outs\images_223.npy
# on image ../outs\images_224.npy
# on image ../outs\images_225.npy
# on image ../outs\images_226.npy
# on image ../outs\images_227.npy
# on image ../outs\images_228.npy
# on image ../outs\images_229.npy
# on image ../outs\images_23.npy
# on image ../outs\images_230.npy
# on image ../outs\images_231.npy
# on image ../outs\images_232.npy
# on image ../outs\images_233.npy
# on image ../outs\images_234.npy
# on image ../outs\images_235.npy
# on image ../outs\images_236.npy
# on image ../outs\images_237.npy
# on image ../outs\images_238.npy
# on image ../outs\images_239.npy
# on image ../outs\images_24.npy
# on image ../outs\images_240.npy
# on image ../outs\images_241.npy
# on image ../outs\images_242.npy
# on image ../outs\images_243.npy
# on image ../outs\images_244.npy
# on image ../outs\images_245.npy
# on image ../outs\images_246.npy
# on image ../outs\images_247.npy
# on image ../outs\images_248.npy
# on image ../outs\images_249.npy
# on image ../outs\images_25.npy
# on image ../outs\images_250.npy
# on image ../outs\images_251.npy
# on image ../outs\images_252.npy
# on image ../outs\images_253.npy
# on image ../outs\images_254.npy
# on image ../outs\images_255.npy
# on image ../outs\images_256.npy
# on image ../outs\images_257.npy
# on image ../outs\images_258.npy
# on image ../outs\images_259.npy
# on image ../outs\images_26.npy
# on image ../outs\images_260.npy
# on image ../outs\images_261.npy
# on image ../outs\images_262.npy
# on image ../outs\images_263.npy
# on image ../outs\images_264.npy
# on image ../outs\images_265.npy
# on image ../outs\images_266.npy
# on image ../outs\images_267.npy
# on image ../outs\images_268.npy
# on image ../outs\images_269.npy
# on image ../outs\images_27.npy
# on image ../outs\images_270.npy
# on image ../outs\images_271.npy
# on image ../outs\images_272.npy
# on image ../outs\images_273.npy
# on image ../outs\images_274.npy
# on image ../outs\images_275.npy
# on image ../outs\images_276.npy
# on image ../outs\images_277.npy
# on image ../outs\images_278.npy
# on image ../outs\images_279.npy
# on image ../outs\images_28.npy
# on image ../outs\images_280.npy
# on image ../outs\images_281.npy
# on image ../outs\images_282.npy
# on image ../outs\images_283.npy
# on image ../outs\images_284.npy
# on image ../outs\images_285.npy
# on image ../outs\images_286.npy
# on image ../outs\images_287.npy
# on image ../outs\images_288.npy
# on image ../outs\images_289.npy
# on image ../outs\images_29.npy
# on image ../outs\images_290.npy
# on image ../outs\images_291.npy
# on image ../outs\images_292.npy
# on image ../outs\images_293.npy
# on image ../outs\images_294.npy
# on image ../outs\images_295.npy
# on image ../outs\images_296.npy
# on image ../outs\images_297.npy
# on image ../outs\images_298.npy
# on image ../outs\images_299.npy
# on image ../outs\images_3.npy
# on image ../outs\images_30.npy
# on image ../outs\images_300.npy
# on image ../outs\images_301.npy
# on image ../outs\images_302.npy
# on image ../outs\images_303.npy
# on image ../outs\images_304.npy
# on image ../outs\images_305.npy
# on image ../outs\images_306.npy
# on image ../outs\images_307.npy
# on image ../outs\images_308.npy
# on image ../outs\images_309.npy
# on image ../outs\images_31.npy
# on image ../outs\images_310.npy
# on image ../outs\images_32.npy
# on image ../outs\images_33.npy
# on image ../outs\images_34.npy
# on image ../outs\images_35.npy
# on image ../outs\images_36.npy
# on image ../outs\images_37.npy
# on image ../outs\images_38.npy
# on image ../outs\images_39.npy
# on image ../outs\images_4.npy
# on image ../outs\images_40.npy
# on image ../outs\images_41.npy
# on image ../outs\images_42.npy
# on image ../outs\images_43.npy
# on image ../outs\images_44.npy
# on image ../outs\images_45.npy
# on image ../outs\images_46.npy
# on image ../outs\images_47.npy
# on image ../outs\images_48.npy
# on image ../outs\images_49.npy
# on image ../outs\images_5.npy
# on image ../outs\images_50.npy
# on image ../outs\images_51.npy
# on image ../outs\images_52.npy
# on image ../outs\images_53.npy
# on image ../outs\images_54.npy
# on image ../outs\images_55.npy
# on image ../outs\images_56.npy
# on image ../outs\images_57.npy
# on image ../outs\images_58.npy
# on image ../outs\images_59.npy
# on image ../outs\images_6.npy
# on image ../outs\images_60.npy
# on image ../outs\images_61.npy
# on image ../outs\images_62.npy
# on image ../outs\images_63.npy
# on image ../outs\images_64.npy
# on image ../outs\images_65.npy
# on image ../outs\images_66.npy
# on image ../outs\images_67.npy
# on image ../outs\images_68.npy
# on image ../outs\images_69.npy
# on image ../outs\images_7.npy
# on image ../outs\images_70.npy
# on image ../outs\images_71.npy
# on image ../outs\images_72.npy
# on image ../outs\images_73.npy
# on image ../outs\images_74.npy
# on image ../outs\images_75.npy
# on image ../outs\images_76.npy
# on image ../outs\images_77.npy
# on image ../outs\images_78.npy
# on image ../outs\images_79.npy
# on image ../outs\images_8.npy
# on image ../outs\images_80.npy
# on image ../outs\images_81.npy
# on image ../outs\images_82.npy
# on image ../outs\images_83.npy
# on image ../outs\images_84.npy
# on image ../outs\images_85.npy
# on image ../outs\images_86.npy
# on image ../outs\images_87.npy
# on image ../outs\images_88.npy
# on image ../outs\images_89.npy
# on image ../outs\images_9.npy
# on image ../outs\images_90.npy
# on image ../outs\images_91.npy
# on image ../outs\images_92.npy
# on image ../outs\images_93.npy
# on image ../outs\images_94.npy
# on image ../outs\images_95.npy
# on image ../outs\images_96.npy
# on image ../outs\images_97.npy
# on image ../outs\images_98.npy
# on image ../outs\images_99.npy

# %%
import matplotlib.pyplot as plt


# %matplotlib notebook

mask_filename = '../outs/masks_0.npy'
masks = np.load(mask_filename)

for i in range(3):
    print ("image %d" % i)
    
    fig,ax = plt.subplots(2,2,figsize=[8,8])

    ax[0,1].imshow(masks[i],cmap='gray') #mascara nodulo annotations.csv correspondente
    
    plt.show()
# Out:
# image 0
# <img src="data:image/png;base64,..." width="800">
# image 1
# <img src="data:image/png;base64,..." width="800">
# image 2
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 3. Creating the training and test datasets

# %%
file_list=glob(output_path+"lungmask_*.npy")


out_images = []      #final set of images
out_nodemasks = []   #final set of nodemasks


for fname in file_list:
    
    print("working on file ", fname)
    
    imgs_to_process = np.load(fname.replace("lungmask","images"))
    masks = np.load(fname)
    node_masks = np.load(fname.replace("lungmask","masks"))
    
    for i in range(len(imgs_to_process)):
        mask = masks[i]
        node_mask = node_masks[i]
        img = imgs_to_process[i]
        new_size = [512,512]   # we're scaling back up to the original size of the image
        img = mask*img         # apply lung mask

        #
        # renormalizing the masked image (in the mask region)
        #
        new_mean = np.mean(img[mask>0])  
        new_std = np.std(img[mask>0])
        
        #
        #  Pulling the background color up to the lower end
        #  of the pixel range for the lungs
        #
        old_min = np.min(img)       # background color
        img[img==old_min] = new_mean-1.2*new_std   # resetting backgound color        
        img = img - new_mean
        img = img / new_std
        
        #make image bounding box  (min row, min col, max row, max col)
        labels = measure.label(mask)
        regions = measure.regionprops(labels)        
        
        #
        # Finding the global min and max row over all regions
        #
        min_row = 512
        max_row = 0
        min_col = 512
        max_col = 0
        for prop in regions:
            B = prop.bbox
            #print(B)
            if min_row > B[0]:
                min_row = B[0]
            if min_col > B[1]:
                min_col = B[1]
            if max_row < B[2]:
                max_row = B[2]
            if max_col < B[3]:
                max_col = B[3]
        width = max_col - min_col
        height = max_row - min_row
        
        if width > height:
            max_row = min_row + width
        else:
            max_col = min_col + height
        
        # 
        # cropping the image down to the bounding box for all regions
        # (there's probably an skimage command that can do this in one line)
        # 
        img = img[min_row:max_row,min_col:max_col]
        mask =  mask[min_row:max_row,min_col:max_col]
        if max_row-min_row <5 or max_col-min_col<5:  # skipping all images with no god regions
            pass
        else:
            # moving range to -1 to 1 to accomodate the resize function
            mean = np.mean(img)
            img = img - mean
            min = np.min(img)
            max = np.max(img)
            img = img/(max-min)
            new_img = resize(img,[512,512])
            new_node_mask = resize(node_mask[min_row:max_row,min_col:max_col],[512,512])
            new_node_mask[new_node_mask > 0] = 1
            out_images.append(new_img)
            out_nodemasks.append(new_node_mask)        

num_images = len(out_images)
#
#  Writing out images and masks as 1 channel arrays for input into network
#
final_images = np.ndarray([num_images,1,512,512],dtype=np.float32)
final_masks = np.ndarray([num_images,1,512,512],dtype=np.float32)
for i in range(num_images):
    final_images[i,0] = out_images[i]
    final_masks[i,0] = out_nodemasks[i]

rand_i = np.random.choice(range(num_images),size=num_images,replace=False)
test_i = int(0.2*num_images)
np.save(output_path+"trainImages.npy",final_images[rand_i[test_i:]])
np.save(output_path+"trainMasks.npy",final_masks[rand_i[test_i:]])
np.save(output_path+"testImages.npy",final_images[rand_i[:test_i]])
np.save(output_path+"testMasks.npy",final_masks[rand_i[:test_i]])
# Out:
# working on file  ../outs\lungmask_0.npy
# working on file  ../outs\lungmask_1.npy
# C:\Users\lucas\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# working on file  ../outs\lungmask_10.npy
# working on file  ../outs\lungmask_100.npy
# working on file  ../outs\lungmask_101.npy
# working on file  ../outs\lungmask_102.npy
# working on file  ../outs\lungmask_103.npy
# working on file  ../outs\lungmask_104.npy
# working on file  ../outs\lungmask_105.npy
# working on file  ../outs\lungmask_106.npy
# working on file  ../outs\lungmask_107.npy
# working on file  ../outs\lungmask_108.npy
# working on file  ../outs\lungmask_109.npy
# working on file  ../outs\lungmask_11.npy
# working on file  ../outs\lungmask_110.npy
# working on file  ../outs\lungmask_111.npy
# working on file  ../outs\lungmask_112.npy
# C:\Users\lucas\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\lucas\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\lucas\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\lucas\Anaconda3\lib\site-packages\numpy\core\_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# C:\Users\lucas\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# working on file  ../outs\lungmask_113.npy
# working on file  ../outs\lungmask_114.npy
# working on file  ../outs\lungmask_115.npy
# working on file  ../outs\lungmask_116.npy
# working on file  ../outs\lungmask_117.npy
# working on file  ../outs\lungmask_118.npy
# working on file  ../outs\lungmask_119.npy
# working on file  ../outs\lungmask_12.npy
# working on file  ../outs\lungmask_120.npy
# working on file  ../outs\lungmask_121.npy
# working on file  ../outs\lungmask_122.npy
# working on file  ../outs\lungmask_123.npy
# working on file  ../outs\lungmask_124.npy
# working on file  ../outs\lungmask_125.npy
# working on file  ../outs\lungmask_126.npy
# working on file  ../outs\lungmask_127.npy
# working on file  ../outs\lungmask_128.npy
# working on file  ../outs\lungmask_129.npy
# working on file  ../outs\lungmask_13.npy
# working on file  ../outs\lungmask_130.npy
# working on file  ../outs\lungmask_131.npy
# working on file  ../outs\lungmask_132.npy
# working on file  ../outs\lungmask_133.npy
# working on file  ../outs\lungmask_134.npy
# working on file  ../outs\lungmask_135.npy
# working on file  ../outs\lungmask_136.npy
# working on file  ../outs\lungmask_137.npy
# working on file  ../outs\lungmask_138.npy
# working on file  ../outs\lungmask_139.npy
# working on file  ../outs\lungmask_14.npy
# working on file  ../outs\lungmask_140.npy
# working on file  ../outs\lungmask_141.npy
# working on file  ../outs\lungmask_142.npy
# working on file  ../outs\lungmask_143.npy
# working on file  ../outs\lungmask_144.npy
# working on file  ../outs\lungmask_145.npy
# working on file  ../outs\lungmask_146.npy
# working on file  ../outs\lungmask_147.npy
# working on file  ../outs\lungmask_148.npy
# working on file  ../outs\lungmask_149.npy
# working on file  ../outs\lungmask_15.npy
# working on file  ../outs\lungmask_150.npy
# working on file  ../outs\lungmask_151.npy
# working on file  ../outs\lungmask_152.npy
# working on file  ../outs\lungmask_153.npy
# working on file  ../outs\lungmask_154.npy
# working on file  ../outs\lungmask_155.npy
# working on file  ../outs\lungmask_156.npy
# working on file  ../outs\lungmask_157.npy
# working on file  ../outs\lungmask_158.npy
# working on file  ../outs\lungmask_159.npy
# working on file  ../outs\lungmask_16.npy
# working on file  ../outs\lungmask_160.npy
# working on file  ../outs\lungmask_161.npy
# working on file  ../outs\lungmask_162.npy
# working on file  ../outs\lungmask_163.npy
# working on file  ../outs\lungmask_164.npy
# working on file  ../outs\lungmask_165.npy
# working on file  ../outs\lungmask_166.npy
# working on file  ../outs\lungmask_167.npy
# working on file  ../outs\lungmask_168.npy
# working on file  ../outs\lungmask_169.npy
# working on file  ../outs\lungmask_17.npy
# working on file  ../outs\lungmask_170.npy
# working on file  ../outs\lungmask_171.npy
# working on file  ../outs\lungmask_172.npy
# working on file  ../outs\lungmask_173.npy
# working on file  ../outs\lungmask_174.npy
# working on file  ../outs\lungmask_175.npy
# working on file  ../outs\lungmask_176.npy
# working on file  ../outs\lungmask_177.npy
# working on file  ../outs\lungmask_178.npy
# working on file  ../outs\lungmask_179.npy
# working on file  ../outs\lungmask_18.npy
# working on file  ../outs\lungmask_180.npy
# working on file  ../outs\lungmask_181.npy
# working on file  ../outs\lungmask_182.npy
# working on file  ../outs\lungmask_183.npy
# working on file  ../outs\lungmask_184.npy
# working on file  ../outs\lungmask_185.npy
# working on file  ../outs\lungmask_186.npy
# working on file  ../outs\lungmask_187.npy
# working on file  ../outs\lungmask_188.npy
# working on file  ../outs\lungmask_189.npy
# working on file  ../outs\lungmask_19.npy
# working on file  ../outs\lungmask_190.npy
# working on file  ../outs\lungmask_191.npy
# working on file  ../outs\lungmask_192.npy
# working on file  ../outs\lungmask_193.npy
# working on file  ../outs\lungmask_194.npy
# working on file  ../outs\lungmask_195.npy
# working on file  ../outs\lungmask_196.npy
# working on file  ../outs\lungmask_197.npy
# working on file  ../outs\lungmask_198.npy
# working on file  ../outs\lungmask_199.npy
# working on file  ../outs\lungmask_2.npy
# working on file  ../outs\lungmask_20.npy
# working on file  ../outs\lungmask_200.npy
# working on file  ../outs\lungmask_201.npy
# working on file  ../outs\lungmask_202.npy
# working on file  ../outs\lungmask_203.npy
# working on file  ../outs\lungmask_204.npy
# working on file  ../outs\lungmask_205.npy
# working on file  ../outs\lungmask_206.npy
# working on file  ../outs\lungmask_207.npy
# working on file  ../outs\lungmask_208.npy
# working on file  ../outs\lungmask_209.npy
# working on file  ../outs\lungmask_21.npy
# working on file  ../outs\lungmask_210.npy
# working on file  ../outs\lungmask_211.npy
# working on file  ../outs\lungmask_212.npy
# working on file  ../outs\lungmask_213.npy
# working on file  ../outs\lungmask_214.npy
# working on file  ../outs\lungmask_215.npy
# working on file  ../outs\lungmask_216.npy
# working on file  ../outs\lungmask_217.npy
# working on file  ../outs\lungmask_218.npy
# working on file  ../outs\lungmask_219.npy
# working on file  ../outs\lungmask_22.npy
# working on file  ../outs\lungmask_220.npy
# working on file  ../outs\lungmask_221.npy
# working on file  ../outs\lungmask_222.npy
# working on file  ../outs\lungmask_223.npy
# working on file  ../outs\lungmask_224.npy
# working on file  ../outs\lungmask_225.npy
# working on file  ../outs\lungmask_226.npy
# working on file  ../outs\lungmask_227.npy
# working on file  ../outs\lungmask_228.npy
# working on file  ../outs\lungmask_229.npy
# working on file  ../outs\lungmask_23.npy
# working on file  ../outs\lungmask_230.npy
# working on file  ../outs\lungmask_231.npy
# working on file  ../outs\lungmask_232.npy
# working on file  ../outs\lungmask_233.npy
# working on file  ../outs\lungmask_234.npy
# working on file  ../outs\lungmask_235.npy
# working on file  ../outs\lungmask_236.npy
# working on file  ../outs\lungmask_237.npy
# working on file  ../outs\lungmask_238.npy
# working on file  ../outs\lungmask_239.npy
# working on file  ../outs\lungmask_24.npy
# working on file  ../outs\lungmask_240.npy
# working on file  ../outs\lungmask_241.npy
# working on file  ../outs\lungmask_242.npy
# working on file  ../outs\lungmask_243.npy
# working on file  ../outs\lungmask_244.npy
# working on file  ../outs\lungmask_245.npy
# working on file  ../outs\lungmask_246.npy
# working on file  ../outs\lungmask_247.npy
# working on file  ../outs\lungmask_248.npy
# working on file  ../outs\lungmask_249.npy
# working on file  ../outs\lungmask_25.npy
# working on file  ../outs\lungmask_250.npy
# working on file  ../outs\lungmask_251.npy
# working on file  ../outs\lungmask_252.npy
# working on file  ../outs\lungmask_253.npy
# working on file  ../outs\lungmask_254.npy
# working on file  ../outs\lungmask_255.npy
# working on file  ../outs\lungmask_256.npy
# working on file  ../outs\lungmask_257.npy
# working on file  ../outs\lungmask_258.npy
# working on file  ../outs\lungmask_259.npy
# working on file  ../outs\lungmask_26.npy
# working on file  ../outs\lungmask_260.npy
# working on file  ../outs\lungmask_261.npy
# working on file  ../outs\lungmask_262.npy
# working on file  ../outs\lungmask_263.npy
# working on file  ../outs\lungmask_264.npy
# working on file  ../outs\lungmask_265.npy
# working on file  ../outs\lungmask_266.npy
# working on file  ../outs\lungmask_267.npy
# working on file  ../outs\lungmask_268.npy
# working on file  ../outs\lungmask_269.npy
# working on file  ../outs\lungmask_27.npy
# working on file  ../outs\lungmask_270.npy
# working on file  ../outs\lungmask_271.npy
# working on file  ../outs\lungmask_272.npy
# working on file  ../outs\lungmask_273.npy
# working on file  ../outs\lungmask_274.npy
# working on file  ../outs\lungmask_275.npy
# working on file  ../outs\lungmask_276.npy
# working on file  ../outs\lungmask_277.npy
# working on file  ../outs\lungmask_278.npy
# working on file  ../outs\lungmask_279.npy
# working on file  ../outs\lungmask_28.npy
# working on file  ../outs\lungmask_280.npy
# working on file  ../outs\lungmask_281.npy
# working on file  ../outs\lungmask_282.npy
# working on file  ../outs\lungmask_283.npy
# working on file  ../outs\lungmask_284.npy
# working on file  ../outs\lungmask_285.npy
# working on file  ../outs\lungmask_286.npy
# working on file  ../outs\lungmask_287.npy
# working on file  ../outs\lungmask_288.npy
# working on file  ../outs\lungmask_289.npy
# working on file  ../outs\lungmask_29.npy
# working on file  ../outs\lungmask_290.npy
# working on file  ../outs\lungmask_291.npy
# working on file  ../outs\lungmask_292.npy
# working on file  ../outs\lungmask_293.npy
# working on file  ../outs\lungmask_294.npy
# working on file  ../outs\lungmask_295.npy
# working on file  ../outs\lungmask_296.npy
# working on file  ../outs\lungmask_297.npy
# working on file  ../outs\lungmask_298.npy
# working on file  ../outs\lungmask_299.npy
# working on file  ../outs\lungmask_3.npy
# working on file  ../outs\lungmask_30.npy
# working on file  ../outs\lungmask_300.npy
# working on file  ../outs\lungmask_301.npy
# working on file  ../outs\lungmask_302.npy
# working on file  ../outs\lungmask_303.npy
# working on file  ../outs\lungmask_304.npy
# working on file  ../outs\lungmask_305.npy
# working on file  ../outs\lungmask_306.npy
# working on file  ../outs\lungmask_307.npy
# working on file  ../outs\lungmask_308.npy
# working on file  ../outs\lungmask_309.npy
# working on file  ../outs\lungmask_31.npy
# working on file  ../outs\lungmask_310.npy
# working on file  ../outs\lungmask_32.npy
# working on file  ../outs\lungmask_33.npy
# working on file  ../outs\lungmask_34.npy
# working on file  ../outs\lungmask_35.npy
# working on file  ../outs\lungmask_36.npy
# working on file  ../outs\lungmask_37.npy
# working on file  ../outs\lungmask_38.npy
# working on file  ../outs\lungmask_39.npy
# working on file  ../outs\lungmask_4.npy
# working on file  ../outs\lungmask_40.npy
# working on file  ../outs\lungmask_41.npy
# working on file  ../outs\lungmask_42.npy
# working on file  ../outs\lungmask_43.npy
# working on file  ../outs\lungmask_44.npy
# working on file  ../outs\lungmask_45.npy
# working on file  ../outs\lungmask_46.npy
# working on file  ../outs\lungmask_47.npy
# working on file  ../outs\lungmask_48.npy
# working on file  ../outs\lungmask_49.npy
# working on file  ../outs\lungmask_5.npy
# working on file  ../outs\lungmask_50.npy
# working on file  ../outs\lungmask_51.npy
# working on file  ../outs\lungmask_52.npy
# working on file  ../outs\lungmask_53.npy
# working on file  ../outs\lungmask_54.npy
# working on file  ../outs\lungmask_55.npy
# working on file  ../outs\lungmask_56.npy
# working on file  ../outs\lungmask_57.npy
# working on file  ../outs\lungmask_58.npy
# working on file  ../outs\lungmask_59.npy
# working on file  ../outs\lungmask_6.npy
# working on file  ../outs\lungmask_60.npy
# working on file  ../outs\lungmask_61.npy
# working on file  ../outs\lungmask_62.npy
# working on file  ../outs\lungmask_63.npy
# working on file  ../outs\lungmask_64.npy
# working on file  ../outs\lungmask_65.npy
# working on file  ../outs\lungmask_66.npy
# working on file  ../outs\lungmask_67.npy
# working on file  ../outs\lungmask_68.npy
# working on file  ../outs\lungmask_69.npy
# working on file  ../outs\lungmask_7.npy
# working on file  ../outs\lungmask_70.npy
# working on file  ../outs\lungmask_71.npy
# working on file  ../outs\lungmask_72.npy
# working on file  ../outs\lungmask_73.npy
# working on file  ../outs\lungmask_74.npy
# working on file  ../outs\lungmask_75.npy
# working on file  ../outs\lungmask_76.npy
# working on file  ../outs\lungmask_77.npy
# working on file  ../outs\lungmask_78.npy
# working on file  ../outs\lungmask_79.npy
# working on file  ../outs\lungmask_8.npy
# working on file  ../outs\lungmask_80.npy
# working on file  ../outs\lungmask_81.npy
# working on file  ../outs\lungmask_82.npy
# working on file  ../outs\lungmask_83.npy
# working on file  ../outs\lungmask_84.npy
# working on file  ../outs\lungmask_85.npy
# working on file  ../outs\lungmask_86.npy
# working on file  ../outs\lungmask_87.npy
# working on file  ../outs\lungmask_88.npy
# working on file  ../outs\lungmask_89.npy
# working on file  ../outs\lungmask_9.npy
# working on file  ../outs\lungmask_90.npy
# working on file  ../outs\lungmask_91.npy
# working on file  ../outs\lungmask_92.npy
# working on file  ../outs\lungmask_93.npy
# working on file  ../outs\lungmask_94.npy
# working on file  ../outs\lungmask_95.npy
# working on file  ../outs\lungmask_96.npy
# working on file  ../outs\lungmask_97.npy
# working on file  ../outs\lungmask_98.npy
# working on file  ../outs\lungmask_99.npy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook



img_filename = '../outs/testImages.npy'
mask_filename = '../outs/testMasks.npy'

imgs = np.load(img_filename)
masks = np.load(mask_filename)

for i in [0,7,9]:
    print ("image %d" % i)
    
    fig,ax = plt.subplots(2,2,figsize=[8,8])
    print(type(masks))
    ax[0,0].imshow(imgs[i,0],cmap='gray') #slice tomografia
    ax[0,1].imshow(masks[i,0],cmap='gray') #mascara nodulo annotations.csv correspondente
    ax[1,0].imshow(imgs[i,0]*masks[i,0],cmap='gray') #mascara aplicada na slice
    
    plt.show()
# Out:
# image 0
# <img src="data:image/png;base64,..." width="800">
# <class 'numpy.ndarray'>
# image 7
# <img src="data:image/png;base64,..." width="800">
# <class 'numpy.ndarray'>
# image 9
# <img src="data:image/png;base64,..." width="800">
# <class 'numpy.ndarray'>
